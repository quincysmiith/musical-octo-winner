# %% [markdown]
# # Setup

# %%
# !pip install gspread-dataframe

# %%
import pandas as pd
from gspread_dataframe import get_as_dataframe, set_with_dataframe

# %% [markdown]
# # Authorise Google Sheets

# %%
# authorise google sheets
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

# %%
# identify the specific google sheet to work with
sht = gc.open_by_key('1t762sD-lHhjPmIednCjxbp_T8waMlsaWW-6DFjgaU4c')

# %% [markdown]
# # Load from Google Sheets

# %%
stadium_worksheet = sht.worksheet("stadiums")

# %%
stadium_data = get_as_dataframe(stadium_worksheet, usecols=[0,1,2,3] )
stadium_data = stadium_data.dropna()

# %%
stadium_data.shape
# Out:
# (20, 4)

# %%
stadium_data
# Out:
#                        Team  ... Capacity
# 0                   Arsenal  ...  38419.0
# 1               Aston Villa  ...  42553.0
# 2           Birmingham City  ...  30079.0
# 3          Blackburn Rovers  ...  31367.0
# 4          Bolton Wanderers  ...  28723.0
# 5         Charlton Athletic  ...  27111.0
# 6                   Chelsea  ...  42360.0
# 7                   Everton  ...  40569.0
# 8                    Fulham  ...  18493.0
# 9              Leeds United  ...  40242.0
# 10           Leicester City  ...  32312.0
# 11                Liverpool  ...  45276.0
# 12          Manchester City  ...  48000.0
# 13        Manchester United  ...  68217.0
# 14            Middlesbrough  ...  35049.0
# 15         Newcastle United  ...  52387.0
# 16               Portsmouth  ...  20220.0
# 17              Southampton  ...  32505.0
# 18        Tottenham Hotspur  ...  36240.0
# 19  Wolverhampton Wanderers  ...  29303.0
#
# [20 rows x 4 columns]

# %% [markdown]
# # Save to Google Sheets

# %%
# read in all tables on html page into a list
datas = pd.read_html("https://en.wikipedia.org/wiki/2003%E2%80%9304_FA_Premier_League")

# %%
len(datas)
# Out:
# 18

# %%
# find the gold
datas[7].head()
# Out:
#    Pos  ...                        Qualification or relegation
# 0    1  ...  Qualification for the Champions League group s...
# 1    2  ...  Qualification for the Champions League group s...
# 2    3  ...  Qualification for the Champions League third q...
# 3    4  ...  Qualification for the Champions League third q...
# 4    5  ...         Qualification for the UEFA Cup first round
#
# [5 rows x 11 columns]

# %%
# identify the worksheet to work with
s1_worksheet = sht.worksheet("Sheet1")

# %%
#save data into the worksheet
set_with_dataframe(s1_worksheet, datas[7])

# %% [markdown]
# # Video tutorial of working with Google Sheets in Python

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('cN7W2EPM-dw', width=800, height=600)
